# %% [markdown]
# <a href="https://colab.research.google.com/github/bayuazra23/Portofolio/blob/master/Capstone_Cleaned.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install emoji
import pandas as pd
import numpy as np
import re
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
import emoji
# !pip install sastrawi
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting emoji
#   Downloading emoji-1.7.0.tar.gz (175 kB)
#      |████████████████████████████████| 175 kB 5.1 MB/s
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171046 sha256=23a3ab2d3b3e42acdef30c4ca437d0d9c701dcb37fc3a0d555a87ef7786d2789
#   Stored in directory: /root/.cache/pip/wheels/8a/4e/b6/57b01db010d17ef6ea9b40300af725ef3e210cb1acfb7ac8b6
# Successfully built emoji
# Installing collected packages: emoji
# Successfully installed emoji-1.7.0
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Capstone/Dataset   - Sheet1 (1).csv')
dataset = dataset.fillna(' ')
dataset
# Out:
#                                                  text  \
# 0   Robot trading forex otomatis dengan hasil trad...
# 1   Net89 adalah Software Trading forex otomatis b...
# 2   Jika anda bing mencari strategi yang cocok unt...
# 3   Raibotlook merupakan system trading yg menggun...
# 4   Software Auto Trading terbaik untuk memudahkan...
# 5   Team pantau news/berita dan pergerakan pasar 2...
# 6   ROBOT AUTO TRADE GOLD 4.0\r\nTrading fully aut...
# 7   Perusahaan yang menciptakan teknologi robot tr...
# 8   Dapatkan potensi keuntungan tanpa harus memili...
# 9   Mencari Robot yg SABTU-MINGGU tetap kasih Cuan...
# 10  PENTING, HARAP DIBACA SAMPAI HABIS\n\nAUTOPILO...
# 11  KELEBIHAN EA FOX\r\n- Sistem Perdagangan yang ...
# 12  ROBOT FOREX UNTUK MEMBANTU ANDA MENGEKSEKUSI M...
# 13  EA INDONESIA PRO (GARUDA IDN) EA INDONESIA di ...
# 14  Keunggulan Investasi Reksa Dana di Bibit\nBibi...
# 15  Sukuk Tabungan Seri ST008 adalah produk invest...
# 16  Deposito Rupiah J Trust adalah simpanan berjan...
# 17  Pilihan Investasi yang Memberi Keuntungan dan ...
# 18  Deposito BCA merupakan pilihan investasi yang ...
# 19  Deposito Rupiah\r\nSimpanan berjangka dalam ma...
# 20  BNI Deposito merupakan simpanan berjangka yang...
# 21  Sukuk Negara Ritel (Sukuk Ritel) adalah produk...
#
#             Nama perusahan/produk  \
# 0                       SmartXBot
# 1                           Net89
# 2                          Quotex
# 3                     Raibot look
# 4                         DNA Pro
# 5                          FIN888
# 6                  Autotrade Gold
# 7                      Fahrenheit
# 8   EA50/PT. SENTRA MEGAH INDOTEK
# 9                         Mark.Ai
# 10                      AVATAR911
# 11                   Robot EA Fox
# 12             Double Marti Trend
# 13               EA Garuda Profit
# 14                          BIBIT
# 15              Sukuk Bunga ST008
# 16           Deposito Bank JTrust
# 17   Deposito Rupiah Bank Mandiri
# 18       Deposito Rupiah Bank BCA
# 19       Deposito Rupiah Bank BRI
# 20       Deposito Rupiah Bank BNI
# 21              Sukuk Ritel SR014
#
#                                               sumber   \
# 0   https://www.lazada.co.id/products/software-tra...
# 1   https://www.tokopedia.com/dgtoys/net89-bot-tra...
# 2                              https://id-quotex.com/
# 3   https://www.facebook.com/Raibotlook-1172395436...
# 4
# 5                     https://www.lpteams.com/fin888/
# 6   https://www.tokopedia.com/kameshop/robot-tradi...
# 7            https://www.instagram.com/p/CUGN5XCBv-a/
# 8                                 https://ea50idn.id/
# 9
# 10  https://shopee.co.id/Autopilot-Profit-Trading-...
# 11  https://www.tokopedia.com/masterforexid/robot-...
# 12  https://www.tokopedia.com/t25shop/ea-robot-for...
# 13  https://www.tokopedia.com/l73/trading-otomatis...
# 14
# 15
# 16
# 17
# 18
# 19
# 20
# 21
#
#                                Kategori Legalitas
# 0                         Trading Robot    ilegal
# 1                         Trading Robot    ilegal
# 2   Scam Binary Options/Futures Trading    ilegal
# 3                         Trading Robot    ilegal
# 4                         Trading Robot    ilegal
# 5                  Trading Robot, Ponzi    ilegal
# 6                         Trading Robot    ilegal
# 7                         Trading Robot    ilegal
# 8                         Trading Robot    ilegal
# 9                         Trading Robot    ilegal
# 10                        Trading Robot    ilegal
# 11                        Trading Robot    ilegal
# 12                        Trading Robot    ilegal
# 13                        Trading Robot    ilegal
# 14                                          legal
# 15                                          legal
# 16                                          legal
# 17                                          legal
# 18                                          legal
# 19                                          legal
# 20                                          legal
# 21                                          legal

# %%
dataset_cleaned = dataset[["text","Legalitas"]]
dataset_cleaned['text'] = dataset_cleaned['text'].str.lower() #lowercase
# ilangin tab
for i in range(0, (len(dataset_cleaned))):
  temp = dataset_cleaned.loc[i, 'text']
  temp = re.sub(r'\n', ' ', temp ) 
#Ilangin angka and simbol
  temp = re.sub('[^a-zA-Z,.?!]+',' ',temp)
#Ilangin Link
  temp = re.sub(r"(https?:\/\/(?:www\.|(?!www))[a-zA-Z0-9][a-zA-Z0-9-]+[a-zA-Z0-9]\.[^\s]{2,}|www\.[a-zA-Z0-9][a-zA-Z0-9-]+[a-zA-Z0-9]\.[^\s]{2,}|https?:\/\/(?:www\.|(?!www))[a-zA-Z0-9]+\.[^\s]{2,}|www\.[a-zA-Z0-9]+\.[^\s]{2,})", "", temp)
#Hapus Emoji dsb
  temp = emoji.demojize(temp)
  temp= re.sub(':[A-Za-z_-]+:', ' ', temp) 
# hapus hashtag
  temp= re.sub(r'#(\S+)', r'\1', temp)
# rapihin spasi
  temp = re.sub('[ ]+',' ',temp)
  # dataset_cleaned['text'][i] = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",temp).split())
  dataset_cleaned['text'][i] = temp
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dataset_cleaned
# Out:
#                                                  text Legalitas
# 0   robot trading forex otomatis dengan hasil trad...    ilegal
# 1   net adalah software trading forex otomatis bua...    ilegal
# 2   jika anda bing mencari strategi yang cocok unt...    ilegal
# 3   raibotlook merupakan system trading yg menggun...    ilegal
# 4   software auto trading terbaik untuk memudahkan...    ilegal
# 5   team pantau news berita dan pergerakan pasar j...    ilegal
# 6   robot auto trade gold . trading fully automati...    ilegal
# 7   perusahaan yang menciptakan teknologi robot tr...    ilegal
# 8   dapatkan potensi keuntungan tanpa harus memili...    ilegal
# 9   mencari robot yg sabtu minggu tetap kasih cuan...    ilegal
# 10  penting, harap dibaca sampai habis autopilot t...    ilegal
# 11  kelebihan ea fox sistem perdagangan yang stabi...    ilegal
# 12  robot forex untuk membantu anda mengeksekusi m...    ilegal
# 13  ea indonesia pro garuda idn ea indonesia di ke...    ilegal
# 14  keunggulan investasi reksa dana di bibit bibit...     legal
# 15  sukuk tabungan seri st adalah produk investasi...     legal
# 16  deposito rupiah j trust adalah simpanan berjan...     legal
# 17  pilihan investasi yang memberi keuntungan dan ...     legal
# 18  deposito bca merupakan pilihan investasi yang ...     legal
# 19  deposito rupiah simpanan berjangka dalam mata ...     legal
# 20  bni deposito merupakan simpanan berjangka yang...     legal
# 21  sukuk negara ritel sukuk ritel adalah produk i...     legal

# %%
# encoding label
encoding = {'legal': 1, 'ilegal':0}
dataset_cleaned = dataset_cleaned.replace(encoding)

# %%
# Stemming
 #import Indonesian Stemmer
def stemmingIndo(str):
    factory = StemmerFactory()
    stemmer = factory.create_stemmer()
    return stemmer.stem(str)

# %%
for i in range(0,len(dataset_cleaned)):
  dataset_cleaned['text'][i] = stemmingIndo(dataset_cleaned['text'][i])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dataset_tokened = dataset_cleaned
for i in range(0, (len(dataset_tokened ))):
  temp = dataset_tokened.loc[i, 'text']
  token_list = word_tokenize(temp)
  # temp = " ".join(token_list)
  dataset_tokened['text'][i] = token_list
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Remove Stopwords
stopwords = []
f = open("/content/drive/MyDrive/Capstone/id.stopwords.02.01.2016.txt", "r")
for line in f:
  line = line.strip()
  stopwords.append(line)

# %%
# for i in range(0, (len(dataset_tokened ))):
dataset_tokened['text']= [ word for word in dataset_tokened['text'] if word not in stopwords]

# %%
for i in range(0, len(dataset_tokened)):
  dataset_cleaned['text'][i] = " ".join(dataset_tokened['text'][i])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# SPlit
X_train, X_test, y_train, y_test = train_test_split(dataset_cleaned['text'], dataset_cleaned['Legalitas'], test_size=0.3, random_state=42)

# %% [markdown]
# #Tokenizing

# %%
# Initialize the Tokenizer class
tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)

# Generate the word index dictionary
tokenizer.fit_on_texts(dataset_cleaned['text'])
word_index = tokenizer.word_index

# %%
vocab_size = 10000
max_length = 120
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"

# Initialize the Tokenizer class
tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)

# Generate the word index dictionary
tokenizer.fit_on_texts(dataset_cleaned['text'])
word_index = tokenizer.word_index

# Generate and pad the training sequences
training_sequences = tokenizer.texts_to_sequences(X_train)
training_padded = pad_sequences(training_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# Generate and pad the testing sequences
testing_sequences = tokenizer.texts_to_sequences(X_test)
testing_padded = pad_sequences(testing_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# Convert the labels lists into numpy arrays
training_labels = np.array(y_train)
testing_labels = np.array(y_test)

# %% [markdown]
# #Model

# %%
# Parameters
embedding_dim = 16
lstm_dim = 32
dense_dim = 24
vocab_size = 1000
max_length = 120
# Model Definition with LSTM
model_lstm = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(lstm_dim)),
    tf.keras.layers.Dense(dense_dim, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Set the training parameters
model_lstm.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# Print the model summary
model_lstm.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_6 (Embedding)     (None, 120, 16)           16000
#
#  bidirectional_6 (Bidirectio  (None, 64)               12544
#  nal)
#
#  dense_12 (Dense)            (None, 24)                1560
#
#  dense_13 (Dense)            (None, 1)                 25
#
# =================================================================
# Total params: 30,129
# Trainable params: 30,129
# Non-trainable params: 0
# _________________________________________________________________

# %%
NUM_EPOCHS = 20

# Train the model
history_lstm = model_lstm.fit(training_padded, training_labels, epochs=NUM_EPOCHS, validation_data=(testing_padded, testing_labels))
# Out:
# Epoch 1/20
# 1/1 [==============================] - 0s 251ms/step - loss: 0.5527 - accuracy: 0.6000 - val_loss: 0.5612 - val_accuracy: 0.7143
# Epoch 2/20
# 1/1 [==============================] - 0s 133ms/step - loss: 0.5299 - accuracy: 0.6000 - val_loss: 0.5394 - val_accuracy: 0.7143
# Epoch 3/20
# 1/1 [==============================] - 0s 115ms/step - loss: 0.5023 - accuracy: 0.6000 - val_loss: 0.5107 - val_accuracy: 0.7143
# Epoch 4/20
# 1/1 [==============================] - 0s 122ms/step - loss: 0.4685 - accuracy: 0.6000 - val_loss: 0.4697 - val_accuracy: 0.7143
# Epoch 5/20
# 1/1 [==============================] - 0s 124ms/step - loss: 0.4274 - accuracy: 0.6667 - val_loss: 0.4086 - val_accuracy: 0.7143
# Epoch 6/20
# 1/1 [==============================] - 0s 110ms/step - loss: 0.3807 - accuracy: 0.8667 - val_loss: 0.3336 - val_accuracy: 0.8571
# Epoch 7/20
# 1/1 [==============================] - 0s 114ms/step - loss: 0.3366 - accuracy: 1.0000 - val_loss: 0.2935 - val_accuracy: 0.8571
# Epoch 8/20
# 1/1 [==============================] - 0s 114ms/step - loss: 0.3044 - accuracy: 1.0000 - val_loss: 0.3184 - val_accuracy: 0.8571
# Epoch 9/20
# 1/1 [==============================] - 0s 116ms/step - loss: 0.2818 - accuracy: 1.0000 - val_loss: 0.3473 - val_accuracy: 0.8571
# Epoch 10/20
# 1/1 [==============================] - 0s 113ms/step - loss: 0.2659 - accuracy: 1.0000 - val_loss: 0.4620 - val_accuracy: 0.8571
# Epoch 11/20
# 1/1 [==============================] - 0s 131ms/step - loss: 0.2518 - accuracy: 1.0000 - val_loss: 0.5765 - val_accuracy: 0.8571
# Epoch 12/20
# 1/1 [==============================] - 0s 115ms/step - loss: 0.2377 - accuracy: 1.0000 - val_loss: 0.6223 - val_accuracy: 0.8571
# Epoch 13/20
# 1/1 [==============================] - 0s 108ms/step - loss: 0.2239 - accuracy: 1.0000 - val_loss: 0.6547 - val_accuracy: 0.8571
# Epoch 14/20
# 1/1 [==============================] - 0s 124ms/step - loss: 0.2095 - accuracy: 1.0000 - val_loss: 0.6849 - val_accuracy: 0.8571
# Epoch 15/20
# 1/1 [==============================] - 0s 126ms/step - loss: 0.1945 - accuracy: 1.0000 - val_loss: 0.7148 - val_accuracy: 0.8571
# Epoch 16/20
# 1/1 [==============================] - 0s 127ms/step - loss: 0.1784 - accuracy: 1.0000 - val_loss: 0.7455 - val_accuracy: 0.8571
# Epoch 17/20
# 1/1 [==============================] - 0s 128ms/step - loss: 0.2218 - accuracy: 0.9333 - val_loss: 0.7514 - val_accuracy: 0.8571
# Epoch 18/20
# 1/1 [==============================] - 0s 123ms/step - loss: 0.1453 - accuracy: 1.0000 - val_loss: 0.7635 - val_accuracy: 0.8571
# Epoch 19/20
# 1/1 [==============================] - 0s 139ms/step - loss: 0.1293 - accuracy: 1.0000 - val_loss: 0.7812 - val_accuracy: 0.8571
# Epoch 20/20
# 1/1 [==============================] - 0s 134ms/step - loss: 0.1133 - accuracy: 1.0000 - val_loss: 0.0816 - val_accuracy: 1.0000

# %%
import time
saved_model_path = "./{}.h5".format(int(time.time()))
model_lstm.save(saved_model_path)
